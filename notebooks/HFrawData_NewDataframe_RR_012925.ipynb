# %%
"""
This script gathers raw txt files from 'HF test' folder, sorts Controls from UUT, converts them to panda
dataframe and then combines them into a single master dataframe that can be used to 
tidy up and reformat the information to allow automated plotting of glass impedance performance, etc.
RR
01/16/2025
"""
import pandas as pd
import glob
import csv

# %%
file_list = glob.glob('../HFdata/*.txt')
List_Controls = []
List_UUT = []
for nm, fln in enumerate(file_list):
    rawFile = fln.lstrip('../HFdata')
    if ('_glass_') in rawFile:
        if ('Controls') in rawFile:
            List_Controls.append(rawFile)
        if ('UUT') in rawFile:
            List_UUT.append(rawFile)
print(List_Controls)
print(List_UUT)
print(f'There are {len(List_Controls)} Control files.')
print(f'There are {len(List_UUT)} UUT files.')
# Out:
# ['\\Controls_10_glass_09_28_33.txt', '\\Controls_11_glass_21_28_33.txt', '\\Controls_12_glass_09_28_34.txt', '\\Controls_13_glass_21_28_35.txt', '\\Controls_14_glass_09_28_35.txt', '\\Controls_15_glass_21_28_36.txt', '\\Controls_16_glass_09_28_38.txt', '\\Controls_17_glass_21_28_39.txt', '\\Controls_18_glass_09_28_39.txt', '\\Controls_19_glass_21_28_39.txt', '\\Controls_1_glass_21_28_29.txt', '\\Controls_20_glass_09_28_40.txt', '\\Controls_21_glass_21_28_40.txt', '\\Controls_22_glass_09_28_40.txt', '\\Controls_23_glass_21_28_41.txt', '\\Controls_24_glass_09_28_42.txt', '\\Controls_25_glass_21_28_42.txt', '\\Controls_26_glass_09_28_43.txt', '\\Controls_27_glass_21_28_43.txt', '\\Controls_28_glass_09_28_44.txt', '\\Controls_29_glass_21_28_45.txt', '\\Controls_2_glass_09_28_29.txt', '\\Controls_30_glass_09_28_45.txt', '\\Controls_31_glass_21_28_46.txt', '\\Controls_32_glass_09_28_47.txt', '\\Controls_33_glass_21_29_35.txt', '\\Controls_34_glass_09_29_36.txt', '\\Controls_35_glass_21_29_37.txt', '\\Controls_36_glass_09_29_37.txt', '\\Controls_37_glass_21_31_10.txt', '\\Controls_38_glass_09_31_11.txt', '\\Controls_39_glass_21_31_11.txt', '\\Controls_3_glass_21_28_30.txt', '\\Controls_40_glass_09_31_12.txt', '\\Controls_41_glass_21_32_43.txt', '\\Controls_42_glass_09_32_44.txt', '\\Controls_43_glass_21_32_44.txt', '\\Controls_44_glass_09_32_45.txt', '\\Controls_45_glass_21_34_16.txt', '\\Controls_46_glass_09_34_17.txt', '\\Controls_47_glass_21_34_18.txt', '\\Controls_48_glass_09_34_19.txt', '\\Controls_49_glass_21_35_50.txt', '\\Controls_4_glass_09_28_31.txt', '\\Controls_50_glass_09_35_50.txt', '\\Controls_51_glass_21_35_50.txt', '\\Controls_52_glass_09_35_51.txt', '\\Controls_53_glass_21_37_38.txt', '\\Controls_54_glass_09_37_38.txt', '\\Controls_55_glass_21_37_38.txt', '\\Controls_56_glass_09_37_38.txt', '\\Controls_57_glass_21_40_13.txt', '\\Controls_58_glass_09_40_14.txt', '\\Controls_59_glass_21_40_15.txt', '\\Controls_5_glass_21_28_31.txt', '\\Controls_60_glass_09_40_15.txt', '\\Controls_61_glass_21_42_40.txt', '\\Controls_6_glass_09_28_31.txt', '\\Controls_7_glass_21_28_32.txt', '\\Controls_8_glass_09_28_32.txt', '\\Controls_9_glass_21_28_32.txt']
# ['\\UUT_10_glass_09_28_33.txt', '\\UUT_11_glass_21_28_33.txt', '\\UUT_12_glass_09_28_34.txt', '\\UUT_13_glass_21_28_35.txt', '\\UUT_14_glass_09_28_35.txt', '\\UUT_15_glass_21_28_36.txt', '\\UUT_16_glass_09_28_38.txt', '\\UUT_17_glass_21_28_39.txt', '\\UUT_18_glass_09_28_39.txt', '\\UUT_19_glass_21_28_39.txt', '\\UUT_1_glass_21_28_29.txt', '\\UUT_20_glass_09_28_40.txt', '\\UUT_21_glass_21_28_40.txt', '\\UUT_22_glass_09_28_40.txt', '\\UUT_23_glass_21_28_41.txt', '\\UUT_24_glass_09_28_42.txt', '\\UUT_25_glass_21_28_42.txt', '\\UUT_26_glass_09_28_43.txt', '\\UUT_27_glass_21_28_43.txt', '\\UUT_28_glass_09_28_44.txt', '\\UUT_29_glass_21_28_45.txt', '\\UUT_2_glass_09_28_29.txt', '\\UUT_30_glass_09_28_45.txt', '\\UUT_31_glass_21_28_46.txt', '\\UUT_32_glass_09_28_47.txt', '\\UUT_33_glass_21_29_35.txt', '\\UUT_34_glass_09_29_36.txt', '\\UUT_35_glass_21_29_37.txt', '\\UUT_36_glass_09_29_37.txt', '\\UUT_37_glass_21_31_10.txt', '\\UUT_38_glass_09_31_11.txt', '\\UUT_39_glass_21_31_11.txt', '\\UUT_3_glass_21_28_30.txt', '\\UUT_40_glass_09_31_12.txt', '\\UUT_41_glass_21_32_43.txt', '\\UUT_42_glass_09_32_44.txt', '\\UUT_43_glass_21_32_44.txt', '\\UUT_44_glass_09_32_45.txt', '\\UUT_45_glass_21_34_16.txt', '\\UUT_46_glass_09_34_17.txt', '\\UUT_47_glass_21_34_18.txt', '\\UUT_48_glass_09_34_19.txt', '\\UUT_49_glass_21_35_50.txt', '\\UUT_4_glass_09_28_31.txt', '\\UUT_50_glass_09_35_50.txt', '\\UUT_51_glass_21_35_50.txt', '\\UUT_52_glass_09_35_51.txt', '\\UUT_53_glass_21_37_38.txt', '\\UUT_54_glass_09_37_38.txt', '\\UUT_55_glass_21_37_38.txt', '\\UUT_56_glass_09_37_38.txt', '\\UUT_57_glass_21_40_13.txt', '\\UUT_58_glass_09_40_14.txt', '\\UUT_59_glass_21_40_15.txt', '\\UUT_5_glass_21_28_31.txt', '\\UUT_60_glass_09_40_15.txt', '\\UUT_61_glass_21_42_40.txt', '\\UUT_6_glass_09_28_31.txt', '\\UUT_7_glass_21_28_32.txt', '\\UUT_8_glass_09_28_32.txt', '\\UUT_9_glass_21_28_32.txt']
# There are 61 Control files.
# There are 61 UUT files.

# %%
# Get the header from first Control file
result = List_Controls[0]
with open(f'../HFdata/{result}','r') as f:
    header_ctrls = f.readline()
    timestampHeader_ctrls = ("Timestamp\t" + header_ctrls)
    print(timestampHeader_ctrls)
header_list_ctrls = timestampHeader_ctrls.split("\t")
header_list_ctrls = header_list_ctrls[:-1]
print(header_list_ctrls)
# Out:
# Timestamp	62309060476	62309060477	62309060478	62309060479	62309060481	62309060482
#
# ['Timestamp', '62309060476', '62309060477', '62309060478', '62309060479', '62309060481', '62309060482']

# %%
# Get the header from first UUT file
result = List_UUT[0]
with open(f'../HFdata/{result}','r') as f:
    header_uuts = f.readline()
    timestampHeader_uuts = ("Timestamp\t" + header_uuts)
    print(timestampHeader_uuts)
header_list_uuts = timestampHeader_uuts.split("\t")
header_list_uuts = header_list_uuts[:-1]
print(header_list_uuts)
# Out:
# Timestamp	62309060419	62309060427	62309060471	62309060472	62309060473	62309060475
#
# ['Timestamp', '62309060419', '62309060427', '62309060471', '62309060472', '62309060473', '62309060475']

# %%
# Merge all control data files into single dataframe
DF_Controls_single = []
for i in range(len(List_Controls)):
    DF_Controls = pd.read_csv(f'../HFdata/{List_Controls[i]}',sep='\t',header=None,skiprows=1)
    DF_Controls = DF_Controls.drop(columns=7)
    DF_Controls_single.append(DF_Controls)
DF_concat_Controls = pd.concat(DF_Controls_single, ignore_index=True) # single dataframe
DF_concat_Controls.columns = header_list_ctrls
print(DF_concat_Controls.head())
# Out:
#       Timestamp  62309060476  62309060477  62309060478  62309060479  \
# 0  1.700029e+09          0.0          0.0       94.746       78.444
# 1  1.700033e+09          0.0          0.0       93.854       77.974
# 2  1.700037e+09          0.0          0.0       92.951       77.367
# 3  1.700041e+09          0.0          0.0       91.940       76.725
# 4  1.700045e+09          0.0          0.0       90.891       75.991
#
#   62309060481  62309060482
# 0     232.312      103.629
# 1     231.795      102.991
# 2     231.174      102.335
# 3     230.193      101.489
# 4     229.143      100.591

# %%
# Merge all UUT data files into single dataframe
DF_UUT_single = []
for i in range(len(List_UUT)):
    DF_UUTs = pd.read_csv(f'../HFdata/{List_UUT[i]}',sep='\t',header=None,skiprows=1)
    DF_UUTs = DF_UUTs.drop(columns=7)
    DF_UUT_single.append(DF_UUTs)
DF_concat_UUTs = pd.concat(DF_UUT_single, ignore_index=True) # single dataframe
DF_concat_UUTs.columns = header_list_uuts
print(DF_concat_UUTs.head())
# Out:
#       Timestamp  62309060419  62309060427  62309060471  62309060472  \
# 0  1.700029e+09      292.367      276.854      266.070      109.499
# 1  1.700033e+09      291.705      276.064      265.387      109.407
# 2  1.700037e+09      290.789      275.138      264.473      108.988
# 3  1.700041e+09      289.730      274.111      263.545      108.733
# 4  1.700045e+09      288.371      272.930      262.288      108.138
#
#    62309060473  62309060475
# 0      147.128      145.097
# 1      146.899      144.828
# 2      146.539      144.570
# 3      146.184      144.014
# 4      145.463      143.432

# %%
DF_Controls_ordered = DF_concat_Controls.sort_values(by='Timestamp') # ascending is the default sequence.
DF_Controls_ordered.to_excel('Controls.xlsx', sheet_name='Controls', index=False) # save copy as excel file.

# %%
DF_UUTs_ordered = DF_concat_UUTs.sort_values(by='Timestamp') # ascending is the default sequence.
DF_UUTs_ordered.to_excel('UUTs.xlsx', sheet_name='UUTs', index=False) # save copy as excel file.

# %%
DF_Controls_ordered.info() # check data types for possible cleaning out
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 687 entries, 112 to 641
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Timestamp    687 non-null    float64
#  1   62309060476  687 non-null    float64
#  2   62309060477  687 non-null    float64
#  3   62309060478  687 non-null    float64
#  4   62309060479  687 non-null    float64
#  5   62309060481  687 non-null    object
#  6   62309060482  687 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 42.9+ KB

# %%
result = DF_Controls_ordered['62309060476'].head(10)
print(result)
# Out:
# 112    262.545
# 113    261.456
# 114    110.807
# 115    115.158
# 116    118.396
# 117    120.099
# 118    120.731
# 119    120.885
# 120    120.330
# 121    119.354
# Name: 62309060476, dtype: float64

# %%
# Plotting data 
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(1,figsize=(20,12))
plt.plot(DF_UUTs_ordered['Timestamp'],DF_UUTs_ordered['62309060419'])
# ax.set_xticks(DF_UUTs_ordered['Timestamp'])
# ax.set_xticklabels(DF_UUTs_ordered['Timestamp'],rotation=45,fontsize=8,color='blue')
listOf_Xticks = np.arange(DF_UUTs_ordered['Timestamp'][0],DF_UUTs_ordered['Timestamp'][686],105431) # diff divided by 25 as intervals
plt.xticks(listOf_Xticks,rotation=45)
listOf_Yticks = np.arange(0,450,50)
plt.yticks(listOf_Yticks)
# df = DF_UUTs_ordered
# df.plot(y=header_list_uuts[1:7],kind='line',figsize=(12,12))
plt.title('UUT HF Resistance Test')
plt.xlabel('Time')
plt.ylabel('Glass Imp.(MegaOhm)')
plt.show()

# %%
df = DF_Controls_ordered
df.plot(y=header_list_ctrls[1:7], kind='line')
plt.title('Controls HF Resistance Test',fontsize=8)
plt.xlabel('Time',fontsize=8)
plt.ylabel('Glass Imp.(MegaOhm)',fontsize=8)
plt.xticks(fontsize=6, color='blue',rotation=45)
plt.yticks(fontsize=6,color='blue')
plt.show()

# %%
# Now we need to go back to clean up bad data (non numerical, out of range) and then rerun the plotter!
